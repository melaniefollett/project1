# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from pprint import pprint

# %%
#Import csv
raw_game_data = pd.read_csv("vgsales-12-4-2019.csv", encoding="UTF-8")
raw_game_data.head()
# Out:
#    Rank                           Name                      basename  \
# 0     1                     Wii Sports                    wii-sports
# 1     2              Super Mario Bros.              super-mario-bros
# 2     3                 Mario Kart Wii                mario-kart-wii
# 3     4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4     5              Wii Sports Resort             wii-sports-resort
#
#       Genre ESRB_Rating Platform         Publisher         Developer  \
# 0    Sports           E      Wii          Nintendo      Nintendo EAD
# 1  Platform         NaN      NES          Nintendo      Nintendo EAD
# 2    Racing           E      Wii          Nintendo      Nintendo EAD
# 3   Shooter         NaN       PC  PUBG Corporation  PUBG Corporation
# 4    Sports           E      Wii          Nintendo      Nintendo EAD
#
#    VGChartz_Score  Critic_Score  ...  NA_Sales  PAL_Sales  JP_Sales  \
# 0             NaN           7.7  ...       NaN        NaN       NaN
# 1             NaN          10.0  ...       NaN        NaN       NaN
# 2             NaN           8.2  ...       NaN        NaN       NaN
# 3             NaN           NaN  ...       NaN        NaN       NaN
# 4             NaN           8.0  ...       NaN        NaN       NaN
#
#    Other_Sales    Year  Last_Update  \
# 0          NaN  2006.0          NaN
# 1          NaN  1985.0          NaN
# 2          NaN  2008.0  11th Apr 18
# 3          NaN  2017.0  13th Nov 18
# 4          NaN  2009.0          NaN
#
#                                                  url  status Vgchartzscore  \
# 0  http://www.vgchartz.com/game/2667/wii-sports/?...       1           NaN
# 1  http://www.vgchartz.com/game/6455/super-mario-...       1           NaN
# 2  http://www.vgchartz.com/game/6968/mario-kart-w...       1           8.7
# 3  http://www.vgchartz.com/game/215988/playerunkn...       1           NaN
# 4  http://www.vgchartz.com/game/24656/wii-sports-...       1           8.8
#
#                                          img_url
# 0  /games/boxart/full_2258645AmericaFrontccc.jpg
# 1                   /games/boxart/8972270ccc.jpg
# 2  /games/boxart/full_8932480AmericaFrontccc.jpg
# 3  /games/boxart/full_8052843AmericaFrontccc.jpg
# 4  /games/boxart/full_7295041AmericaFrontccc.jpg
#
# [5 rows x 23 columns]

# %%
#Filter columns to only ones we need for analysis
base_game_df = raw_game_data.loc[:, ["Name", "Genre", "Platform", "Critic_Score", "Global_Sales", "NA_Sales",
                                     "PAL_Sales", "JP_Sales", "Other_Sales", "Year"]]

#Rename columns
base_game_df = base_game_df.rename(columns={"Critic_Score": "Critic Score", "Global_Sales": "Global Sales", "NA_Sales": "NA Sales",
                                           "PAL_Sales": "PAL Sales", "JP_Sales": "JP Sales", "Other_Sales": "Other Sales"})

base_game_df
# Out:
#                                 Name             Genre Platform  Critic Score  \
# 0                         Wii Sports            Sports      Wii           7.7
# 1                  Super Mario Bros.          Platform      NES          10.0
# 2                     Mario Kart Wii            Racing      Wii           8.2
# 3      PlayerUnknown's Battlegrounds           Shooter       PC           NaN
# 4                  Wii Sports Resort            Sports      Wii           8.0
# ...                              ...               ...      ...           ...
# 55787                    Indivisible      Role-Playing       PC           NaN
# 55788                     Lost Ember         Adventure       PC           NaN
# 55789                     Lost Ember         Adventure      PS4           NaN
# 55790                     Lost Ember         Adventure     XOne           NaN
# 55791                     Falcon Age  Action-Adventure      PS4           NaN
#
#        Global Sales  NA Sales  PAL Sales  JP Sales  Other Sales    Year
# 0               NaN       NaN        NaN       NaN          NaN  2006.0
# 1               NaN       NaN        NaN       NaN          NaN  1985.0
# 2               NaN       NaN        NaN       NaN          NaN  2008.0
# 3               NaN       NaN        NaN       NaN          NaN  2017.0
# 4               NaN       NaN        NaN       NaN          NaN  2009.0
# ...             ...       ...        ...       ...          ...     ...
# 55787           NaN       NaN        NaN       NaN          NaN  2019.0
# 55788           NaN       NaN        NaN       NaN          NaN  2019.0
# 55789           NaN       NaN        NaN       NaN          NaN  2019.0
# 55790           NaN       NaN        NaN       NaN          NaN  2019.0
# 55791           NaN       NaN        NaN       NaN          NaN     NaN
#
# [55792 rows x 10 columns]

# %%
#Filter Year to 2009-2019
game_df = base_game_df[(base_game_df['Year'] >= 2013) & (base_game_df['Year'] <= 2017)]
#game_df = base_game_df[base_game_df["Year"] >= 2014]
game_df
# Out:
#                                          Name         Genre Platform  \
# 3               PlayerUnknown's Battlegrounds       Shooter       PC
# 19                         Grand Theft Auto V        Action      PS3
# 20                         Grand Theft Auto V        Action      PS4
# 28                                Pokemon X/Y  Role-Playing      3DS
# 31                           Pokemon Sun/Moon  Role-Playing      3DS
# ...                                       ...           ...      ...
# 55756                                 Yodanji  Role-Playing       NS
# 55758        Yono and the Celestial Elephants     Adventure       NS
# 55759                            Yooka-Laylee      Platform       NS
# 55775                        ZOMBIE GOLD RUSH        Action       NS
# 55778  Zoo Tycoon: Ultimate Animal Collection    Simulation     XOne
#
#        Critic Score  Global Sales  NA Sales  PAL Sales  JP Sales  Other Sales  \
# 3               NaN           NaN       NaN        NaN       NaN          NaN
# 19              9.4         20.32      6.37       9.85      0.99         3.12
# 20              9.7         19.39      6.06       9.71      0.60         3.02
# 28              8.9           NaN       NaN        NaN       NaN          NaN
# 31              9.0           NaN       NaN        NaN       NaN          NaN
# ...             ...           ...       ...        ...       ...          ...
# 55756           NaN           NaN       NaN        NaN       NaN          NaN
# 55758           NaN           NaN       NaN        NaN       NaN          NaN
# 55759           NaN           NaN       NaN        NaN       NaN          NaN
# 55775           NaN           NaN       NaN        NaN       NaN          NaN
# 55778           NaN           NaN       NaN        NaN       NaN          NaN
#
#          Year
# 3      2017.0
# 19     2013.0
# 20     2014.0
# 28     2013.0
# 31     2016.0
# ...       ...
# 55756  2017.0
# 55758  2017.0
# 55759  2017.0
# 55775  2017.0
# 55778  2017.0
#
# [8985 rows x 10 columns]

# %%
game_df2 = game_df.loc[:, ["Genre", "Global Sales", "Year"]]
game_df2.head()

#drop NaN's
game_df3 = game_df2.dropna()
game_df3
# Out:
#           Genre  Global Sales    Year
# 19       Action         20.32  2013.0
# 20       Action         19.39  2014.0
# 32       Action         15.86  2013.0
# 34      Shooter         15.09  2015.0
# 50      Shooter         13.40  2017.0
# ...         ...           ...     ...
# 21141  Fighting          0.00  2013.0
# 21148      Misc          0.00  2014.0
# 21152    Puzzle          0.00  2013.0
# 21162      Misc          0.00  2014.0
# 21190    Action          0.00  2016.0
#
# [3178 rows x 3 columns]

# %%
game_df3 = game_df3.replace({"Action": "Action Adventure", "Action-Adventure": "Action Adventure", "Adventure": "Action Adventure", "Shooter": "Action Adventure",
    "Role-Playing": "MMO/Role-Playing", "MMO": "MMO/Role-Playing", "Visual Novel": "MMO/Role-Playing",
    "Sports": "Sports/Simulation", "Simulation": "Sports/Simulation", "Racing": "Sports/Simulation",
    "Puzzle": "Puzzle/Party", "Party": "Puzzle/Party", "Music": "Puzzle/Party", "Board Game": "Puzzle/Party", "Strategy": "Puzzle/Party",
    "Education": "MISC", "Platform": "MISC", "Misc": "MISC"})
game_df3
# Out:
#                   Genre  Global Sales    Year
# 19     Action Adventure         20.32  2013.0
# 20     Action Adventure         19.39  2014.0
# 32     Action Adventure         15.86  2013.0
# 34     Action Adventure         15.09  2015.0
# 50     Action Adventure         13.40  2017.0
# ...                 ...           ...     ...
# 21141          Fighting          0.00  2013.0
# 21148              MISC          0.00  2014.0
# 21152      Puzzle/Party          0.00  2013.0
# 21162              MISC          0.00  2014.0
# 21190  Action Adventure          0.00  2016.0
#
# [3178 rows x 3 columns]

# %%
# Group genres together
game_year = game_df3.groupby(['Genre', 'Year'])
# Get the total global sales per year
yearly_sales = game_year['Global Sales'].sum()
# Chart the Data

yearly_sales
# Out:
# Genre              Year
# Action Adventure   2013.0    171.04
#                    2014.0    161.07
#                    2015.0    135.98
#                    2016.0    112.87
#                    2017.0     93.87
# Fighting           2013.0      7.49
#                    2014.0      5.94
#                    2015.0      9.61
#                    2016.0      3.99
#                    2017.0      5.79
# MISC               2013.0     28.42
#                    2014.0     48.42
#                    2015.0      5.56
#                    2016.0     11.01
#                    2017.0     17.53
# MMO/Role-Playing   2013.0      8.80
#                    2014.0     21.03
#                    2015.0     38.46
#                    2016.0     24.38
#                    2017.0     25.38
# Puzzle/Party       2013.0     12.74
#                    2014.0      8.75
#                    2015.0     12.46
#                    2016.0      9.17
#                    2017.0     10.47
# Sports/Simulation  2013.0     56.75
#                    2014.0     59.15
#                    2015.0     54.17
#                    2016.0     53.07
#                    2017.0     56.10
# Name: Global Sales, dtype: float64

# %%
genre_sales = pd.DataFrame({
    "Global Sales": yearly_sales
})
genre_sales = pd.DataFrame(genre_sales).reset_index(['Genre', 'Year'])
genre_sales
# Out:
#                 Genre    Year  Global Sales
# 0    Action Adventure  2013.0        171.04
# 1    Action Adventure  2014.0        161.07
# 2    Action Adventure  2015.0        135.98
# 3    Action Adventure  2016.0        112.87
# 4    Action Adventure  2017.0         93.87
# 5            Fighting  2013.0          7.49
# 6            Fighting  2014.0          5.94
# 7            Fighting  2015.0          9.61
# 8            Fighting  2016.0          3.99
# 9            Fighting  2017.0          5.79
# 10               MISC  2013.0         28.42
# 11               MISC  2014.0         48.42
# 12               MISC  2015.0          5.56
# 13               MISC  2016.0         11.01
# 14               MISC  2017.0         17.53
# 15   MMO/Role-Playing  2013.0          8.80
# 16   MMO/Role-Playing  2014.0         21.03
# 17   MMO/Role-Playing  2015.0         38.46
# 18   MMO/Role-Playing  2016.0         24.38
# 19   MMO/Role-Playing  2017.0         25.38
# 20       Puzzle/Party  2013.0         12.74
# 21       Puzzle/Party  2014.0          8.75
# 22       Puzzle/Party  2015.0         12.46
# 23       Puzzle/Party  2016.0          9.17
# 24       Puzzle/Party  2017.0         10.47
# 25  Sports/Simulation  2013.0         56.75
# 26  Sports/Simulation  2014.0         59.15
# 27  Sports/Simulation  2015.0         54.17
# 28  Sports/Simulation  2016.0         53.07
# 29  Sports/Simulation  2017.0         56.10

# %%
genre_sales = genre_sales.pivot(index="Year", columns="Genre", values="Global Sales")
genre_sales
# Out:
# Genre   Action Adventure  Fighting   MISC  MMO/Role-Playing  Puzzle/Party  \
# Year
# 2013.0            171.04      7.49  28.42              8.80         12.74
# 2014.0            161.07      5.94  48.42             21.03          8.75
# 2015.0            135.98      9.61   5.56             38.46         12.46
# 2016.0            112.87      3.99  11.01             24.38          9.17
# 2017.0             93.87      5.79  17.53             25.38         10.47
#
# Genre   Sports/Simulation
# Year
# 2013.0              56.75
# 2014.0              59.15
# 2015.0              54.17
# 2016.0              53.07
# 2017.0              56.10

# %%
genre_sales = genre_sales.reset_index()
genre_sales
# Out:
# Genre  index    Year  Action Adventure  Fighting   MISC  MMO/Role-Playing  \
# 0          0  2013.0            171.04      7.49  28.42              8.80
# 1          1  2014.0            161.07      5.94  48.42             21.03
# 2          2  2015.0            135.98      9.61   5.56             38.46
# 3          3  2016.0            112.87      3.99  11.01             24.38
# 4          4  2017.0             93.87      5.79  17.53             25.38
#
# Genre  Puzzle/Party  Sports/Simulation
# 0             12.74              56.75
# 1              8.75              59.15
# 2             12.46              54.17
# 3              9.17              53.07
# 4             10.47              56.10

# %%
#genre_sales.groupby("Genre").plot(y="Global Sales", figsize=(10,5), marker='.', markersize=10, title='Genre Global Sales by Year')


plt.figure(figsize=(20,20))
plt.plot(genre_sales['Year'], genre_sales['Action Adventure'])
plt.plot(genre_sales['Year'], genre_sales['Fighting'])
plt.plot(genre_sales['Year'], genre_sales['MISC'])
plt.plot(genre_sales['Year'], genre_sales['MMO/Role-Playing'])
plt.plot(genre_sales['Year'], genre_sales['Puzzle/Party'])
plt.plot(genre_sales['Year'], genre_sales['Sports/Simulation'])


plt.title('Genre Global Sales by Year', fontsize=36)
plt.xlabel('Year', fontsize=24)
plt.ylabel('Global Sales (m)', fontsize=24)
plt.legend(['Action Adventure', 'Fighting', 'MISC', 'MMO/Role-Playing', 'Puzzle/Party', 'Sports/Simulation'],loc="upper right", prop={'size': 20})
plt.show
plt.tight_layout()
plt.savefig('../Genre_Global_sa.png')
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
