# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from pprint import pprint

# %%
#Import csv
raw_game_data = pd.read_csv("vgsales-12-4-2019.csv")
raw_game_data.head()
# Out:
#    Rank                           Name                      basename  \
# 0     1                     Wii Sports                    wii-sports
# 1     2              Super Mario Bros.              super-mario-bros
# 2     3                 Mario Kart Wii                mario-kart-wii
# 3     4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4     5              Wii Sports Resort             wii-sports-resort
#
#       Genre ESRB_Rating Platform         Publisher         Developer  \
# 0    Sports           E      Wii          Nintendo      Nintendo EAD
# 1  Platform         NaN      NES          Nintendo      Nintendo EAD
# 2    Racing           E      Wii          Nintendo      Nintendo EAD
# 3   Shooter         NaN       PC  PUBG Corporation  PUBG Corporation
# 4    Sports           E      Wii          Nintendo      Nintendo EAD
#
#    VGChartz_Score  Critic_Score  ...  NA_Sales  PAL_Sales  JP_Sales  \
# 0             NaN           7.7  ...       NaN        NaN       NaN
# 1             NaN          10.0  ...       NaN        NaN       NaN
# 2             NaN           8.2  ...       NaN        NaN       NaN
# 3             NaN           NaN  ...       NaN        NaN       NaN
# 4             NaN           8.0  ...       NaN        NaN       NaN
#
#    Other_Sales    Year  Last_Update  \
# 0          NaN  2006.0          NaN
# 1          NaN  1985.0          NaN
# 2          NaN  2008.0  11th Apr 18
# 3          NaN  2017.0  13th Nov 18
# 4          NaN  2009.0          NaN
#
#                                                  url  status Vgchartzscore  \
# 0  http://www.vgchartz.com/game/2667/wii-sports/?...       1           NaN
# 1  http://www.vgchartz.com/game/6455/super-mario-...       1           NaN
# 2  http://www.vgchartz.com/game/6968/mario-kart-w...       1           8.7
# 3  http://www.vgchartz.com/game/215988/playerunkn...       1           NaN
# 4  http://www.vgchartz.com/game/24656/wii-sports-...       1           8.8
#
#                                          img_url
# 0  /games/boxart/full_2258645AmericaFrontccc.jpg
# 1                   /games/boxart/8972270ccc.jpg
# 2  /games/boxart/full_8932480AmericaFrontccc.jpg
# 3  /games/boxart/full_8052843AmericaFrontccc.jpg
# 4  /games/boxart/full_7295041AmericaFrontccc.jpg
#
# [5 rows x 23 columns]

# %%
#Filter columns to only ones we need for analysis
base_game_df = raw_game_data.loc[:, ["Name", "Genre", "Platform", "Critic_Score", "Global_Sales", "NA_Sales",
                                     "PAL_Sales", "JP_Sales", "Other_Sales", "Year"]]
base_game_df
# Out:
#                                 Name             Genre Platform  Critic_Score  \
# 0                         Wii Sports            Sports      Wii           7.7
# 1                  Super Mario Bros.          Platform      NES          10.0
# 2                     Mario Kart Wii            Racing      Wii           8.2
# 3      PlayerUnknown's Battlegrounds           Shooter       PC           NaN
# 4                  Wii Sports Resort            Sports      Wii           8.0
# ...                              ...               ...      ...           ...
# 55787                    Indivisible      Role-Playing       PC           NaN
# 55788                     Lost Ember         Adventure       PC           NaN
# 55789                     Lost Ember         Adventure      PS4           NaN
# 55790                     Lost Ember         Adventure     XOne           NaN
# 55791                     Falcon Age  Action-Adventure      PS4           NaN
#
#        Global_Sales  NA_Sales  PAL_Sales  JP_Sales  Other_Sales    Year
# 0               NaN       NaN        NaN       NaN          NaN  2006.0
# 1               NaN       NaN        NaN       NaN          NaN  1985.0
# 2               NaN       NaN        NaN       NaN          NaN  2008.0
# 3               NaN       NaN        NaN       NaN          NaN  2017.0
# 4               NaN       NaN        NaN       NaN          NaN  2009.0
# ...             ...       ...        ...       ...          ...     ...
# 55787           NaN       NaN        NaN       NaN          NaN  2019.0
# 55788           NaN       NaN        NaN       NaN          NaN  2019.0
# 55789           NaN       NaN        NaN       NaN          NaN  2019.0
# 55790           NaN       NaN        NaN       NaN          NaN  2019.0
# 55791           NaN       NaN        NaN       NaN          NaN     NaN
#
# [55792 rows x 10 columns]

# %%
#Filter Year to 2000-2019
game_df = base_game_df[base_game_df["Year"] >= 2000]
game_df
# Out:
#                                 Name         Genre Platform  Critic_Score  \
# 0                         Wii Sports        Sports      Wii           7.7
# 2                     Mario Kart Wii        Racing      Wii           8.2
# 3      PlayerUnknown's Battlegrounds       Shooter       PC           NaN
# 4                  Wii Sports Resort        Sports      Wii           8.0
# 6              New Super Mario Bros.      Platform       DS           9.1
# ...                              ...           ...      ...           ...
# 55786          In the Valley of Gods     Adventure       PC           NaN
# 55787                    Indivisible  Role-Playing       PC           NaN
# 55788                     Lost Ember     Adventure       PC           NaN
# 55789                     Lost Ember     Adventure      PS4           NaN
# 55790                     Lost Ember     Adventure     XOne           NaN
#
#        Global_Sales  NA_Sales  PAL_Sales  JP_Sales  Other_Sales    Year
# 0               NaN       NaN        NaN       NaN          NaN  2006.0
# 2               NaN       NaN        NaN       NaN          NaN  2008.0
# 3               NaN       NaN        NaN       NaN          NaN  2017.0
# 4               NaN       NaN        NaN       NaN          NaN  2009.0
# 6               NaN       NaN        NaN       NaN          NaN  2006.0
# ...             ...       ...        ...       ...          ...     ...
# 55786           NaN       NaN        NaN       NaN          NaN  2019.0
# 55787           NaN       NaN        NaN       NaN          NaN  2019.0
# 55788           NaN       NaN        NaN       NaN          NaN  2019.0
# 55789           NaN       NaN        NaN       NaN          NaN  2019.0
# 55790           NaN       NaN        NaN       NaN          NaN  2019.0
#
# [42368 rows x 10 columns]
